# %%
import pandas as pd
import numpy as np
import re
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter

# Load dataset
df = pd.read_csv("customer_complaints_1.csv")

# Preprocessing
def preprocess(text):
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', '', text)
    return text

# Apply preprocessing
df['clean_text'] = df['text'].apply(preprocess)

# TF-IDF
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(df['clean_text'])

# Clustering
k = 3
km = KMeans(n_clusters=k, random_state=0)
df['cluster'] = km.fit_predict(X)

# Show result
print(df[['text', 'cluster']].head())

# Purity
purity = max(Counter(df['cluster']).values()) / len(df)
print("Purity:", purity)
# Out:
#                                                 text  cluster
# 0  I used to love Comcast. Until all these consta...        0
# 1  I'm so over Comcast! The worst internet provid...        0
# 2  If I could give them a negative star or no sta...        0
# 3  I've had the worst experiences so far since in...        1
# 4  Check your contract when you sign up for Comca...        0
# Purity: 0.42105263157894735
